# %% [markdown]
# # Pandas
# Pandas is a popular open-source data analysis and manipulation library in Python. It provides data structures and functions needed to work efficiently with structured data, such as tables or time series.
#
# Key Features of Pandas:
# Data Structures
#
# Series: A one-dimensional labeled array (like a column in Excel).
#
# DataFrame: A two-dimensional table with labeled axes (like an Excel spreadsheet).
#
# Data Manipulation:
#
# Filtering, sorting, and transforming data.
# Handling missing values.
# Merging and joining datasets.
#
# Reading & Writing Data:
#
# Supports various formats like CSV, Excel, JSON, SQL, and more.
#
# Statistical Analysis:
#
# Supports descriptive statistics, group-by operations, and pivot tables.
# Integration
#
# Works well with NumPy, Matplotlib, and other data science libraries.

# %%
import numpy as np
import pandas as pd

# %%
train=pd.read_csv('data/titanicdata.csv')
df=train.copy()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 2. Make DataFrame¶

# %%
df_empty=pd.DataFrame()
df_empty.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_empty.shape
# Out:
# (0, 0)

# %%
employee_dict={'Name':['A','B','C'],'Age':[24,34,28],'Roll':[1,2,3]}
employee_dict
# Out:
# {'Name': ['A', 'B', 'C'], 'Age': [24, 34, 28], 'Roll': [1, 2, 3]}

# %%
df_student=pd.DataFrame(employee_dict).reset_index(drop=True)
df_student.head()
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   34     2
# 2    C   28     3

# %% [markdown]
# # 3. Handling null values¶

# %%
import numpy as np
import pandas as pd

# %%
train=pd.read_csv('data/titanicdata.csv')
df=train.copy()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# /var/folders/7z/5qb9wcyx7z9b5_ff36bxqt8c0000gn/T/ipykernel_35881/694922604.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Sex'].fillna(df['Sex'].mode(),inplace=True)

# %%
df['Sex'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # 4. Update/Add new column(s).¶

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Sex']=df['Sex'].map({'male':'0','female':1})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df['last_name']=df['Name'].apply(lambda x:x.split(',')[0])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen

# %%
df['first_name']=df['Name'].apply(lambda x:' '.join(x.split(',')[1:]))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name
# 0                              Mr. Owen Harris
# 1   Mrs. John Bradley (Florence Briggs Thayer)
# 2                                  Miss. Laina
# 3           Mrs. Jacques Heath (Lily May Peel)
# 4                            Mr. William Henry

# %%
df['ThirdAndMen']=df.apply(lambda row:int(row['Pclass']==3 and row['Sex']=="0"),axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdAndMen
# 0                              Mr. Owen Harris            1
# 1   Mrs. John Bradley (Florence Briggs Thayer)            0
# 2                                  Miss. Laina            0
# 3           Mrs. Jacques Heath (Lily May Peel)            0
# 4                            Mr. William Henry            1

# %%
def findAgeGroupFun(ageValue):
    if ageValue<=18:
        return 1
    elif ageValue>=19 and ageValue<=45:
        return 2
    else:
        return 3

# %%
df['Age_group']=df['Age'].apply(lambda x:findAgeGroupFun(x))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdAndMen  Age_group
# 0                              Mr. Owen Harris            1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)            0          2
# 2                                  Miss. Laina            0          2
# 3           Mrs. Jacques Heath (Lily May Peel)            0          2
# 4                            Mr. William Henry            1          2

# %% [markdown]
# # 5. Deleting columns¶

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# 4            373450   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdAndMen  Age_group
# 0                              Mr. Owen Harris            1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)            0          2
# 2                                  Miss. Laina            0          2
# 3           Mrs. Jacques Heath (Lily May Peel)            0          2
# 4                            Mr. William Henry            1          2

# %%
df=df.drop(['Ticket'],axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#       Fare Cabin Embarked  last_name  \
# 0   7.2500   NaN        S     Braund
# 1  71.2833   C85        C    Cumings
# 2   7.9250   NaN        S  Heikkinen
# 3  53.1000  C123        S   Futrelle
# 4   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdAndMen  Age_group
# 0                              Mr. Owen Harris            1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)            0          2
# 2                                  Miss. Laina            0          2
# 3           Mrs. Jacques Heath (Lily May Peel)            0          2
# 4                            Mr. William Henry            1          2

# %% [markdown]
# # 6. Renaming columns¶

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#       Fare Cabin Embarked  last_name  \
# 0   7.2500   NaN        S     Braund
# 1  71.2833   C85        C    Cumings
# 2   7.9250   NaN        S  Heikkinen
# 3  53.1000  C123        S   Futrelle
# 4   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdAndMen  Age_group
# 0                              Mr. Owen Harris            1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)            0          2
# 2                                  Miss. Laina            0          2
# 3           Mrs. Jacques Heath (Lily May Peel)            0          2
# 4                            Mr. William Henry            1          2

# %%
df=df.rename(columns={'Sex':'Gender','Name':'Full Name'})

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Full Name Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris      0  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1  38.0      1
# 2                             Heikkinen, Miss. Laina      1  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1  35.0      1
# 4                           Allen, Mr. William Henry      0  35.0      0
#
#    Parch     Fare Cabin Embarked  last_name  \
# 0      0   7.2500   NaN        S     Braund
# 1      0  71.2833   C85        C    Cumings
# 2      0   7.9250   NaN        S  Heikkinen
# 3      0  53.1000  C123        S   Futrelle
# 4      0   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdAndMen  Age_group
# 0                              Mr. Owen Harris            1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)            0          2
# 2                                  Miss. Laina            0          2
# 3           Mrs. Jacques Heath (Lily May Peel)            0          2
# 4                            Mr. William Henry            1          2

# %% [markdown]
# # 7 Slicing DataFrame¶

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Full Name Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris      0  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1  38.0      1
# 2                             Heikkinen, Miss. Laina      1  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1  35.0      1
# 4                           Allen, Mr. William Henry      0  35.0      0
#
#    Parch     Fare Cabin Embarked  last_name  \
# 0      0   7.2500   NaN        S     Braund
# 1      0  71.2833   C85        C    Cumings
# 2      0   7.9250   NaN        S  Heikkinen
# 3      0  53.1000  C123        S   Futrelle
# 4      0   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdAndMen  Age_group
# 0                              Mr. Owen Harris            1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)            0          2
# 2                                  Miss. Laina            0          2
# 3           Mrs. Jacques Heath (Lily May Peel)            0          2
# 4                            Mr. William Henry            1          2

# %%
df_second_class=df[df['Pclass']==2].reset_index(drop=True)

# %%
df_second_class.head()
# Out:
#    PassengerId  Survived  Pclass                            Full Name Gender  \
# 0           10         1       2  Nasser, Mrs. Nicholas (Adele Achem)      1
# 1           16         1       2     Hewlett, Mrs. (Mary D Kingcome)       1
# 2           18         1       2         Williams, Mr. Charles Eugene      0
# 3           21         0       2                 Fynney, Mr. Joseph J      0
# 4           22         1       2                Beesley, Mr. Lawrence      0
#
#          Age  SibSp  Parch     Fare Cabin Embarked last_name  \
# 0  14.000000      1      0  30.0708   NaN        C    Nasser
# 1  55.000000      0      0  16.0000   NaN        S   Hewlett
# 2  29.699118      0      0  13.0000   NaN        S  Williams
# 3  35.000000      0      0  26.0000   NaN        S    Fynney
# 4  34.000000      0      0  13.0000   D56        S   Beesley
#
#                      first_name  ThirdAndMen  Age_group
# 0   Mrs. Nicholas (Adele Achem)            0          1
# 1       Mrs. (Mary D Kingcome)             0          3
# 2            Mr. Charles Eugene            0          2
# 3                  Mr. Joseph J            0          2
# 4                  Mr. Lawrence            0          2

# %% [markdown]
# # Female with age>65

# %%
df_aged=df[(df['Age']>60)]

# %%
df_aged.head()
# Out:
#      PassengerId  Survived  Pclass                       Full Name Gender  \
# 33            34         0       2           Wheadon, Mr. Edward H      0
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius      0
# 96            97         0       1       Goldschmidt, Mr. George B      0
# 116          117         0       3            Connors, Mr. Patrick      0
# 170          171         0       1       Van der hoef, Mr. Wyckoff      0
#
#       Age  SibSp  Parch     Fare Cabin Embarked     last_name  \
# 33   66.0      0      0  10.5000   NaN        S       Wheadon
# 54   65.0      0      1  61.9792   B30        C         Ostby
# 96   71.0      0      0  34.6542    A5        C   Goldschmidt
# 116  70.5      0      0   7.7500   NaN        Q       Connors
# 170  61.0      0      0  33.5000   B19        S  Van der hoef
#
#                    first_name  ThirdAndMen  Age_group
# 33               Mr. Edward H            0          3
# 54    Mr. Engelhart Cornelius            0          3
# 96               Mr. George B            0          3
# 116               Mr. Patrick            1          3
# 170               Mr. Wyckoff            0          3

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 0    577
# 1    314
# Name: count, dtype: int64

# %%
df_aged['Gender'].value_counts()
# Out:
# Gender
# 0    19
# 1     3
# Name: count, dtype: int64

# %%
df_aged=df[(df['Age']>60) &(df['Gender']=="0")]
df_aged.head()
# Out:
#      PassengerId  Survived  Pclass                       Full Name Gender  \
# 33            34         0       2           Wheadon, Mr. Edward H      0
# 54            55         0       1  Ostby, Mr. Engelhart Cornelius      0
# 96            97         0       1       Goldschmidt, Mr. George B      0
# 116          117         0       3            Connors, Mr. Patrick      0
# 170          171         0       1       Van der hoef, Mr. Wyckoff      0
#
#       Age  SibSp  Parch     Fare Cabin Embarked     last_name  \
# 33   66.0      0      0  10.5000   NaN        S       Wheadon
# 54   65.0      0      1  61.9792   B30        C         Ostby
# 96   71.0      0      0  34.6542    A5        C   Goldschmidt
# 116  70.5      0      0   7.7500   NaN        Q       Connors
# 170  61.0      0      0  33.5000   B19        S  Van der hoef
#
#                    first_name  ThirdAndMen  Age_group
# 33               Mr. Edward H            0          3
# 54    Mr. Engelhart Cornelius            0          3
# 96               Mr. George B            0          3
# 116               Mr. Patrick            1          3
# 170               Mr. Wyckoff            0          3

# %% [markdown]
# # 8  Slicing dataframe columns

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Full Name Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris      0  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1  38.0      1
# 2                             Heikkinen, Miss. Laina      1  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1  35.0      1
# 4                           Allen, Mr. William Henry      0  35.0      0
#
#    Parch     Fare Cabin Embarked  last_name  \
# 0      0   7.2500   NaN        S     Braund
# 1      0  71.2833   C85        C    Cumings
# 2      0   7.9250   NaN        S  Heikkinen
# 3      0  53.1000  C123        S   Futrelle
# 4      0   8.0500   NaN        S      Allen
#
#                                     first_name  ThirdAndMen  Age_group
# 0                              Mr. Owen Harris            1          2
# 1   Mrs. John Bradley (Florence Briggs Thayer)            0          2
# 2                                  Miss. Laina            0          2
# 3           Mrs. Jacques Heath (Lily May Peel)            0          2
# 4                            Mr. William Henry            1          2

# %%
df1=df[['Full Name','Age','Pclass','Gender']]

# %%
df1.head()
# Out:
#                                            Full Name   Age  Pclass Gender
# 0                            Braund, Mr. Owen Harris  22.0       3      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1      1
# 2                             Heikkinen, Miss. Laina  26.0       3      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1      1
# 4                           Allen, Mr. William Henry  35.0       3      0

# %%
data_types=['int16','int32','int64','float16','float32','float64']

# %%
df_num=df.select_dtypes(include=data_types)

# %%
df_num.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  ThirdAndMen  \
# 0            1         0       3  22.0      1      0   7.2500            1
# 1            2         1       1  38.0      1      0  71.2833            0
# 2            3         1       3  26.0      0      0   7.9250            0
# 3            4         1       1  35.0      1      0  53.1000            0
# 4            5         0       3  35.0      0      0   8.0500            1
#
#    Age_group
# 0          2
# 1          2
# 2          2
# 3          2
# 4          2

# %%
df_categorical=df.select_dtypes(include=['object'])

# %%
df_categorical.head()
# Out:
#                                            Full Name Gender Cabin Embarked  \
# 0                            Braund, Mr. Owen Harris      0   NaN        S
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1   C85        C
# 2                             Heikkinen, Miss. Laina      1   NaN        S
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1  C123        S
# 4                           Allen, Mr. William Henry      0   NaN        S
#
#    last_name                                   first_name
# 0     Braund                              Mr. Owen Harris
# 1    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2  Heikkinen                                  Miss. Laina
# 3   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4      Allen                            Mr. William Henry
